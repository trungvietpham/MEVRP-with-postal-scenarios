# %%
cd ..
# Out:
# d:\VIetpt\DANO support

# %%
import json 
with open('scenarios/sender_side.json', 'r') as f:
    data = json.load(f)

# %%
key_list = list(data['vehicle'].keys())
for i in range(len(data['vehicle'])):
    print(f"Route: {data['vehicle'][key_list[i]]}")
    print(f"Distance: {data['distance'][key_list[i]]}, No. of node: {len(data['vehicle'][key_list[i]])}")
    if input('Wait') == '0': break
# Out:
# Route: ['100000', '115000', '110220', '110050', '110130', '101006', '118733', '111770', '118728', '125400', '125080', '126415', '125600', '125656', '127010', '131220', '134000', '132200', '132617', '139018', '136090', '140700', '142000', '139040', '140600', '140900', '140100', '141400', '141300', '142250', '142240', '150000', '142160', '142134', '142219', '137313', '137800', '139000', '136020', '138000', '136908', '138300', '138324', '143510', '143320', '143314', '124600', '124068', '125000', '124700', '122913', '118028', '120065', '118600', '112200', '118734', '100901', '115545', '111100', '116000', '112400', '113100', '113360', '112618', '113900', '115070', '114089', '115356', '128181', '127800', '129000', '128200', '122080', '128539', '128252', '128300', '129049', '134030', '128540', '136000', '134710', '158700', '100000']
# Distance: 203.1174839485005, No. of node: 83
# ...
